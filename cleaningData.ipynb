# %% [markdown]
# DATA Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("MLOps_Acadimic__DataSET.csv")
df.head()
# Out:
#                       SchoolDepartment  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                 ProjectTitle  Finish Time  \
# 0  Add Documents to 2020 Core Committee Page          NaN
# 1     White River High School Election Video          NaN
# 2               Pet License Roster Web Edits          NaN
# 3                      FJC Shred Event Flyer          NaN
# 4     Create Artwork for new Large Dropboxes          NaN
#
#                        Email  \
# 0  kfoulstone0@instagram.com
# 1  kfoulstone0@instagram.com
# 2  kfoulstone0@instagram.com
# 3  kfoulstone0@instagram.com
# 4  kfoulstone0@instagram.com
#
#                                        RequiredSkill               Professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                          GainedSkill strartingOrAsgnmtDate  \
# 0                                Website Programming            04-03-2019
# 1                                                NaN            04-03-2019
# 2                                Website Programming            04-03-2019
# 3  Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                                NaN            11-03-2019
#
#           Hour
# 0  07:51:00 PM
# 1  07:56:00 PM
# 2  08:12:00 PM
# 3     22:27:00
# 4     15:38:00

# %%
df.shape
# Out:
# (2139, 9)

# %%
df.drop(['Finish Time'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                       SchoolDepartment  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                 ProjectTitle                      Email  \
# 0  Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1     White River High School Election Video  kfoulstone0@instagram.com
# 2               Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                      FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4     Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
#
#                                        RequiredSkill               Professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                          GainedSkill strartingOrAsgnmtDate  \
# 0                                Website Programming            04-03-2019
# 1                                                NaN            04-03-2019
# 2                                Website Programming            04-03-2019
# 3  Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                                NaN            11-03-2019
#
#           Hour
# 0  07:51:00 PM
# 1  07:56:00 PM
# 2  08:12:00 PM
# 3     22:27:00
# 4     15:38:00

# %%
df.dropna(subset=['Professors'],inplace=True)

# %%
df.head()
# Out:
#                       SchoolDepartment  \
# 0      Quality Assurance and Risk Mgmt
# 1      Quality Assurance and Risk Mgmt
# 2     Quality Assurance and Risk Manag
# 3     Quality Assurance and Risk Manag
# 4  Quality Assurance & Risk Management
#
#                                 ProjectTitle                      Email  \
# 0  Add Documents to 2020 Core Committee Page  kfoulstone0@instagram.com
# 1     White River High School Election Video  kfoulstone0@instagram.com
# 2               Pet License Roster Web Edits  kfoulstone0@instagram.com
# 3                      FJC Shred Event Flyer  kfoulstone0@instagram.com
# 4     Create Artwork for new Large Dropboxes  kfoulstone0@instagram.com
#
#                                        RequiredSkill               Professors  \
# 0                                Website Programming  Fatima Zahra El Idrissi
# 1                       Video Editing and Production  Fatima Zahra El Idrissi
# 2                                Website Programming  Fatima Zahra El Idrissi
# 3  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
# 4  Graphic Design/Marketing (Posters, Brochures, ...  Fatima Zahra El Idrissi
#
#                                          GainedSkill strartingOrAsgnmtDate  \
# 0                                Website Programming            04-03-2019
# 1                                                NaN            04-03-2019
# 2                                Website Programming            04-03-2019
# 3  Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                                NaN            11-03-2019
#
#           Hour
# 0  07:51:00 PM
# 1  07:56:00 PM
# 2  08:12:00 PM
# 3     22:27:00
# 4     15:38:00

# %%
df.fillna({'GainedSkill': 'No Skill', 'Email': 'Unknoun','RequiredSkill': 'Unknoun','ProjectTitle':'Unknoun'}, inplace=True)

# %%
df.tail()
# Out:
#                       SchoolDepartment  \
# 2128    Academic Affairs and Staff Dev
# 2129   Quality Assurance and Risk Mgmt
# 2130  Quality Assurance and Risk Manag
# 2131  Engineering Leadership and Strat
# 2132       Eng Leadership and Strategy
#
#                                            ProjectTitle    Email  \
# 2128              2019 Standing Ovation Awards nominees  unvalid
# 2129  Pierce County to continue mobile voting after ...  unvalid
# 2130  Pierce County to continue mobile voting after ...  unvalid
# 2131         Flag lowering to honor Deputy Cooper Dyson  unvalid
# 2132         Flag lowering to honor Deputy Cooper Dyson  unvalid
#
#                                           RequiredSkill  \
# 2128                Internal and External Communication
# 2129                           News Writing and Editing
# 2130                           News Writing and Editing
# 2131  Internal and External Communication, News Writ...
# 2132  Internal and External Communication, News Writ...
#
#                           Professors  \
# 2128  Samira Alaoui, Rachid Khattabi
# 2129    Samira Alaoui, Nawal Chraibi
# 2130    Samira Alaoui, Nawal Chraibi
# 2131    Samira Alaoui, Nawal Chraibi
# 2132    Samira Alaoui, Nawal Chraibi
#
#                                             GainedSkill strartingOrAsgnmtDate  \
# 2128  Proofreading and Quality Assurance, Website Pr...            2019-08-05
# 2129  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2130  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2131  Internal and External Communication, News and ...            23-12-2019
# 2132  Internal and External Communication, News and ...            2019-12-23
#
#              Hour
# 2128     19:30:00
# 2129     00:00:00
# 2130     23:40:00
# 2131  12:00:00 AM
# 2132  11:35:00 PM

# %%
df.isnull().sum()
# Out:
# SchoolDepartment         0
# ProjectTitle             0
# Email                    0
# RequiredSkill            0
# Professors               0
# GainedSkill              0
# strartingOrAsgnmtDate    0
# Hour                     0
# dtype: int64

# %%
from dateutil import parser

def standardize_dates(date_series, target_format="%Y-%m-%d"):
    def parse_date(date):
        try:
            return parser.parse(date).strftime(target_format)
        except Exception as e:
            return None  # Handle invalid dates gracefully

    return date_series.apply(parse_date)

# Standardize the dates
df['strartingOrAsgnmtDate'] = standardize_dates(df['strartingOrAsgnmtDate'])

print(df['strartingOrAsgnmtDate'])
# Out:
# 0       2019-04-03
# 1       2019-04-03
# 2       2019-04-03
# 3       2019-03-04
# 4       2019-11-03
#            ...
# 2128    2019-08-05
# 2129    2019-12-03
# 2130    2019-12-03
# 2131    2019-12-23
# 2132    2019-12-23
# Name: strartingOrAsgnmtDate, Length: 2133, dtype: object

# %%
df.isnull().sum()
# Out:
# SchoolDepartment         0
# ProjectTitle             0
# Email                    0
# RequiredSkill            0
# Professors               0
# GainedSkill              0
# strartingOrAsgnmtDate    0
# Hour                     0
# dtype: int64

# %%
from datetime import datetime


# Standardize time format (24-hour)
def standardize_time(time_str):
    try:
        # Parse time, infer 12/24-hour format
        parsed_time = datetime.strptime(time_str, "%I:%M:%S %p") if "AM" in time_str or "PM" in time_str else datetime.strptime(time_str, "%H:%M:%S")
        return parsed_time.strftime("%H:%M:%S")  # Return standardized 24-hour format
    except ValueError:
        return None  # Handle invalid formats gracefully

df['Hour'] = df['Hour'].apply(standardize_time)

print(df['Hour'])
# Out:
# 0       19:51:00
# 1       19:56:00
# 2       20:12:00
# 3       22:27:00
# 4       15:38:00
#           ...
# 2128    19:30:00
# 2129    00:00:00
# 2130    23:40:00
# 2131    00:00:00
# 2132    23:35:00
# Name: Hour, Length: 2133, dtype: object

# %%
# Function to clean and standardize the 'SchoolDepartment' column
def clean_school_department(column):
    # Define corrections for inconsistent entries
    corrections = {
        'quality assurance and risk managementement': 'quality assurance and risk management',
        'tech communication and media': 'technical communication and media',
        'eng leadership and strategy': 'engineering leadership and strategy',
        'engineering leadership and strat': 'engineering leadership and strategy',
        'environmental and civil engin': 'environmental and civil engineering',
        'environmental and civil eng': 'environmental and civil engineering',
        'financial eng': 'financial engineering',
        'financial enginering': 'financial engineering',
        'academic affairs and staff dev': 'academic affairs and staff development',
        'academic affairs and staff devel': 'academic affairs and staff development',
        'governance and poli stud': 'governance and policy studies',
        'governance and policy stud': 'governance and policy studies',
        'social impact eng': 'social impact engineering',
        'social impact engin': 'social impact engineering',
        'urban planning and public infrastr': 'urban planning and public infrastructure',
        'urban planning and public infra': 'urban planning and public infrastructure',
        'humanitarian eng and outreach': 'humanitarian engineering and outreach',
        'humanitarian engineering and outr': 'humanitarian engineering and outreach',
        'industrial and systems engin': 'industrial and systems engineering',
        'industrial and systems eng': 'industrial and systems engineering',
        'facilities and maintenance engin': 'facilities and maintenance engineering',
        'facilities and maintenance eng': 'facilities and maintenance engineering',
        'partnerships and external collab': 'partnerships and external collaboration',
        'partnerships and external collabor': 'partnerships and external collaboration',
        'youth outreach and train': 'youth outreach and training',
        'documentation and knowledge managementement': 'documentation and knowledge management',
        'financial analysis and managementement': 'financial analysis and management',
        'regulatory eng': 'regulatory engineering',
        'security systems eng': 'security systems engineering',
        'security systems engin': 'security systems engineering',
        'ethics and professional cond': 'ethics and professional conduct',
        'ethics and prof conduct': 'ethics and professional conduct',
        'accreditation and academic standar': 'accreditation and academic standards',
        'research and technical publicat': 'research and technical publications',
        'research and technical publ': 'research and technical publications',
        'safety engineering and crisis managementement': 'safety engineering and crisis management',
        'safety eng and crisis managementement': 'safety engineering and crisis management',
        'biomedical engin': 'biomedical engineering',
        'regulatory engin': 'regulatory engineering',
        'hu': 'humanitarian engineering and outreach'  # Assuming "hu" is shorthand
    }

    # Standardize and clean the column
    return (column
            .str.lower()  # Convert to lowercase
            .str.replace(' & ', ' and ', regex=False)  # Replace '&' with 'and'
            .str.replace('mgmt', 'management', regex=False)  # Expand abbreviations
            .str.replace('manag', 'management', regex=False)  # Correct partial words
            .str.strip()  # Remove leading/trailing whitespaces
            .replace(corrections)  # Apply corrections
           )

# Apply the cleaning function to the 'SchoolDepartment' column
df['SchoolDepartment'] = clean_school_department(df['SchoolDepartment'])

# Display the cleaned column's unique values
print(df['SchoolDepartment'].unique())
# Out:
# ['quality assurance and risk management'
#  'technical communication and media' 'engineering leadership and strategy'
#  'academic affairs and staff development' 'technical comm and media'
#  'environmental and civil engineering' 'financal engineering'
#  'governance and policy studies'
#  'safety engineering and crisis management' 'financial engineering'
#  'social impact engineering' 'ethics and professional conduct'
#  'legal and compliance engineering'
#  'urban planning and public infrastructure' 'legal and compliance engin'
#  'administrative and procedural engin'
#  'administrative and procedural engineering'
#  'partnerships and external collaboration'
#  'humanitarian engineering and outreach'
#  'facilities and maintenance engineering'
#  'industrial and systems engineering' 'regulatory engineering'
#  'security systems engineering' 'youth outreach and training'
#  'documentation and knowledge management'
#  'hydraulics and water resources eng' 'legal and compliance eng'
#  'administrative and procedural eng'
#  'accreditation and academic standards' 'biomedical engineering'
#  'financial analysis and management' 'research and technical publications']

# %%
# Out:
#                             SchoolDepartment  \
# 0      quality assurance and risk management
# 1      quality assurance and risk management
# 2      quality assurance and risk management
# 3      quality assurance and risk management
# 4      quality assurance and risk management
# ...                                      ...
# 2128  academic affairs and staff development
# 2129   quality assurance and risk management
# 2130   quality assurance and risk management
# 2131     engineering leadership and strategy
# 2132     engineering leadership and strategy
#
#                                            ProjectTitle  \
# 0             Add Documents to 2020 Core Committee Page
# 1                White River High School Election Video
# 2                          Pet License Roster Web Edits
# 3                                 FJC Shred Event Flyer
# 4                Create Artwork for new Large Dropboxes
# ...                                                 ...
# 2128              2019 Standing Ovation Awards nominees
# 2129  Pierce County to continue mobile voting after ...
# 2130  Pierce County to continue mobile voting after ...
# 2131         Flag lowering to honor Deputy Cooper Dyson
# 2132         Flag lowering to honor Deputy Cooper Dyson
#
#                           Email  \
# 0     kfoulstone0@instagram.com
# 1     kfoulstone0@instagram.com
# 2     kfoulstone0@instagram.com
# 3     kfoulstone0@instagram.com
# 4     kfoulstone0@instagram.com
# ...                         ...
# 2128                    unvalid
# 2129                    unvalid
# 2130                    unvalid
# 2131                    unvalid
# 2132                    unvalid
#
#                                           RequiredSkill  \
# 0                                   Website Programming
# 1                          Video Editing and Production
# 2                                   Website Programming
# 3     Graphic Design/Marketing (Posters, Brochures, ...
# 4     Graphic Design/Marketing (Posters, Brochures, ...
# ...                                                 ...
# 2128                Internal and External Communication
# 2129                           News Writing and Editing
# 2130                           News Writing and Editing
# 2131  Internal and External Communication, News Writ...
# 2132  Internal and External Communication, News Writ...
#
#                           Professors  \
# 0            Fatima Zahra El Idrissi
# 1            Fatima Zahra El Idrissi
# 2            Fatima Zahra El Idrissi
# 3            Fatima Zahra El Idrissi
# 4            Fatima Zahra El Idrissi
# ...                              ...
# 2128  Samira Alaoui, Rachid Khattabi
# 2129    Samira Alaoui, Nawal Chraibi
# 2130    Samira Alaoui, Nawal Chraibi
# 2131    Samira Alaoui, Nawal Chraibi
# 2132    Samira Alaoui, Nawal Chraibi
#
#                                             GainedSkill strartingOrAsgnmtDate  \
# 0                                   Website Programming            2019-04-03
# 1                                              No Skill            2019-04-03
# 2                                   Website Programming            2019-04-03
# 3     Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                              No Skill            2019-11-03
# ...                                                 ...                   ...
# 2128  Proofreading and Quality Assurance, Website Pr...            2019-08-05
# 2129  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2130  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2131  Internal and External Communication, News and ...            2019-12-23
# 2132  Internal and External Communication, News and ...            2019-12-23
#
#           Hour
# 0     19:51:00
# 1     19:56:00
# 2     20:12:00
# 3     22:27:00
# 4     15:38:00
# ...        ...
# 2128  19:30:00
# 2129  00:00:00
# 2130  23:40:00
# 2131  00:00:00
# 2132  23:35:00
#
# [2133 rows x 8 columns]

# %%
# Function to clean and standardize skills columns
def clean_skills_column(column):
    # Define corrections for inconsistent entries in skills columns
    skill_corrections = {
        'website programming': 'web programming',
        'graphic design/marketing (posters, brochures, flyers)': 'graphic design and marketing',
        'video editing and production': 'video production and editing',
        'technical documentation/writing': 'technical writing',
        'database managementment': 'database management',
        'ui/ux designing': 'ui/ux design',
        'project managementment': 'project management',
        'graphic designing': 'graphic design',
        'technical docum': 'technical documentation',
        'machine learning and ai': 'machine learning and artificial intelligence',
    }

    # Standardize and clean the column
    return (column
            .str.lower()  # Convert to lowercase
            .str.replace('designing', 'design', regex=False)  # Normalize "designing" to "design"
            .str.replace('managementment', 'management', regex=False)  # Correct double suffixes
            .str.strip()  # Remove leading/trailing whitespaces
            .replace(skill_corrections)  # Apply corrections
           )

# Apply the cleaning function to the 'RequiredSkill' and 'GainedSkill' columns
df['RequiredSkill'] = clean_skills_column(df['RequiredSkill'])
df['GainedSkill'] = clean_skills_column(df['GainedSkill'])

# Check unique values for both columns after cleaning
required_skills_unique = df['RequiredSkill'].unique()
gained_skills_unique = df['GainedSkill'].unique()

required_skills_unique, gained_skills_unique
# Out:
# (array(['web programming', 'video production and editing',
#         'graphic design/marketing (posters, brochures, reports)',
#         'social media strategy', 'technical writing',
#         'news writing and editing',
#         'strategic planning and project management',
#         'graphic design/marketing (posters, brochures, reports), social media strategy',
#         'unknoun',
#         'website programming, graphic design/marketing (posters, brochures, reports)',
#         'graphic design/marketing (posters, brochures, reports), social media strategy, website programming, technical writing',
#         'video editing and production, website programming',
#         'graphic design/marketing (posters, brochures, reports), social media strategy, website programming',
#         'social media strategy, graphic design/marketing (posters, brochures, reports)',
#         'graphic design/marketing (posters, brochures, reports), video editing and production',
#         'internal and external communication, news writing and editing, graphic design/marketing (posters, brochures, reports)',
#         'internal and external communication, public relations',
#         'social media strategy, video editing and production, website programming',
#         'printed material (posters, brochures, reports)',
#         'internal and external communication',
#         'internal and external communication, graphic design/marketing (posters, brochures, reports), social media strategy, strategic planning and project management',
#         'strategic planning and project management, graphic design/marketing (posters, brochures, reports)',
#         'graphic design/marketing (brochures, posters, reports)',
#         'graphic design/marketing (brochures, posters, reports), communication planning/strategy',
#         'communication planning/strategy, technical writing',
#         'communication planning/strategy',
#         'communication planning/strategy, graphic design/marketing (brochures, posters, reports)',
#         'social media strategy, technical writing',
#         'graphic design/marketing (brochures, posters, reports), social media strategy',
#         'communication planning/strategy, social media strategy, graphic design/marketing (brochures, posters, reports)',
#         'communication planning/strategy, internal and external communication, social media strategy',
#         'communication planning/strategy, news writing and editing, website programming',
#         'website programming, graphic design/marketing (brochures, posters, reports)',
#         'communication planning/strategy, internal and external communication',
#         'communication planning/strategy, graphic design/marketing (brochures, posters, reports), social media strategy',
#         'communication planning/strategy, data collection tools, graphic design/marketing (brochures, posters, reports)',
#         'news writing and editing, social media strategy',
#         'news writing and editing, video editing and production',
#         'communication planning/strategy, public relations, news writing and editing',
#         'social media strategy, communication planning/strategy',
#         'communication planning/strategy, internal and external communication, social media strategy, video editing and production',
#         'social media strategy, graphic design/marketing (brochures, posters, reports)',
#         'communication planning/strategy, internal and external communication, data collection tools, website programming',
#         'communication planning/strategy, news writing and editing, video editing and production',
#         'graphic design/marketing (brochures, posters, reports), social media strategy, news writing and editing',
#         'issue and risk management', 'public relations',
#         'event management and logistics',
#         'news writing and editing, website programming, social media strategy',
#         'public relations, website programming, news writing and editing',
#         'graphic design/marketing (posters, brochures, reports), technical writing',
#         'social media strategy, public relations',
#         'public relations, social media strategy',
#         'strategic planning and project management, public relations, technical writing, website programming, news writing and editing',
#         'video editing and production, website programming, social media strategy',
#         'issue and risk management, social media strategy, video editing and production, website programming',
#         'strategic planning and project management, issue and risk management, public relations, news writing and editing, graphic design/marketing (posters, brochures, reports), social media strategy, website programming',
#         'website programming, video editing and production, social media strategy',
#         'graphic design/marketing (posters, brochures, reports), website programming',
#         'public relations, technical writing',
#         'internal and external communication, video editing and production',
#         'video editing and production, internal and external communication',
#         'website programming, communication planning/strategy',
#         'website programming, internal and external communication',
#         'graphic design/marketing (brochures, posters, reports), website programming',
#         'video editing and production, social media strategy',
#         'website programming, video editing and production',
#         'internal and external communication, website programming',
#         'website programming, data collection tools',
#         'event management and logistics, graphic design/marketing (posters, brochures, reports), news writing and editing, social media strategy, website programming',
#         'strategic planning and project management, website programming',
#         'internal and external communication, graphic design/marketing (posters, brochures, reports)',
#         'event management and logistics, social media strategy, graphic design/marketing (posters, brochures, reports)',
#         'internal and external communication, technical writing',
#         'social media strategy, news writing and editing, graphic design/marketing (posters, brochures, reports)',
#         'strategic planning and project management, technical writing',
#         'social media strategy, news writing and editing',
#         'graphic design/marketing (posters, brochures, reports), strategic planning and project management',
#         'social media strategy, graphic design/marketing (posters, brochures, reports), news writing and editing',
#         'strategic planning and project management, graphic design/marketing (posters, brochures, reports), technical writing',
#         'graphic design/marketing (posters, brochures, reports), event management and logistics',
#         'event management and logistics, strategic planning and project management, internal and external communication',
#         'website programming, strategic planning and project management',
#         'graphic design/marketing (posters, brochures, reports), website programming, social media strategy, news writing and editing',
#         'strategic planning and project management, event management and logistics, technical writing, video editing and production, website programming',
#         'strategic planning and project management, graphic design/marketing (posters, brochures, reports), social media strategy, video editing and production',
#         'website programming, graphic design/marketing (posters, brochures, reports), strategic planning and project management, technical writing',
#         'website programming, social media strategy, strategic planning and project management',
#         'internal and external communication, graphic design/marketing (posters, brochures, reports), website programming',
#         'internal and external communication, website programming, graphic design/marketing (posters, brochures, reports)',
#         'news writing and editing, social media strategy, website programming, public relations, graphic design/marketing (posters, brochures, reports)',
#         'strategic planning and project management, social media strategy, website programming',
#         'website programming, strategic planning and project management, data collection tools',
#         'strategic planning and project management, graphic design/marketing (posters, brochures, reports), social media strategy, website programming',
#         'strategic planning and project management, social media strategy',
#         'social media strategy, event management and logistics, news writing and editing',
#         'strategic planning and project management, news writing and editing, social media strategy',
#         'social media strategy, video editing and production',
#         'data collection tools, website programming',
#         'communication planning/strategy, public relations',
#         'news writing and editing, website programming, graphic design/marketing (brochures, posters, reports), communication planning/strategy, event/open houses',
#         'news writing and editing, event/open houses, social media strategy',
#         'internal and external communication, graphic design/marketing (brochures, posters, reports)',
#         'video editing and production, communication planning/strategy',
#         'event/open houses, social media strategy, graphic design/marketing (brochures, posters, reports), news writing and editing',
#         'website programming, social media strategy, communication planning/strategy',
#         'social media strategy, graphic design/marketing (brochures, posters, reports), video editing and production',
#         'executive-level documentation',
#         'graphic design/marketing (brochures, posters, reports), internal and external communication',
#         'communication planning/strategy, website programming',
#         'website programming, communication planning/strategy, data collection tools',
#         'social media strategy, event/open houses, graphic design/marketing (brochures, posters, reports), website programming, news writing and editing',
#         'internal and external communication, event/open houses',
#         'website programming, graphic design/marketing (brochures, posters, reports), communication planning/strategy',
#         'news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports), website programming',
#         'news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)',
#         'news writing and editing, website programming, graphic design/marketing (brochures, posters, reports), social media strategy',
#         'news writing and editing, graphic design/marketing (brochures, posters, reports), social media strategy',
#         'graphic design/marketing (brochures, posters, reports), website programming, social media strategy',
#         'event/open houses, graphic design/marketing (brochures, posters, reports), social media strategy',
#         'news writing and editing, website programming',
#         'event/open houses, social media strategy',
#         'graphic design/marketing (brochures, posters, reports), social media strategy, communication planning/strategy',
#         'social media strategy, news writing and editing, website programming, graphic design/marketing (brochures, posters, reports)',
#         'news writing and editing, graphic design/marketing (brochures, posters, reports), website programming, social media strategy',
#         'website programming, graphic design/marketing (brochures, posters, reports), social media strategy, news writing and editing',
#         'social media strategy, graphic design/marketing (brochures, posters, reports), technical writing',
#         'technical writing, communication planning/strategy',
#         'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy',
#         'social media strategy, website programming, video editing and production',
#         'graphic design/marketing (brochures, posters, reports), event/open houses, website programming, data collection tools',
#         'technical writing, internal and external communication',
#         'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy, website programming, public relations',
#         'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy, video editing and production',
#         'data collection tools, communication planning/strategy, website programming',
#         'internal and external communication, graphic design/marketing (brochures, posters, reports), website programming',
#         'graphic design/marketing (brochures, posters, reports), news writing and editing, social media strategy, event/open houses',
#         'website programming, communication planning/strategy, news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)',
#         'event/open houses, social media strategy, communication planning/strategy',
#         'website programming, social media strategy, news writing and editing',
#         'website programming, news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)',
#         'communication planning/strategy, event/open houses, graphic design/marketing (brochures, posters, reports), website programming',
#         'event/open houses, social media strategy, news writing and editing, graphic design/marketing (brochures, posters, reports), website programming',
#         'data collection tools',
#         'internal and external communication, website programming, graphic design/marketing (brochures, posters, reports)',
#         'technical writing, event management and logistics',
#         'event management and logistics, graphic design/marketing (posters, brochures, reports)',
#         'graphic design/marketing (posters, brochures, reports), internal and external communication',
#         'internal and external communication, video editing and production, website programming',
#         'strategic planning and project management, internal and external communication',
#         'news writing and editing, internal and external communication',
#         'internal and external communication, data collection tools',
#         'communication planning/strategy, website programming, internal and external communication',
#         'event/open houses, graphic design/marketing (brochures, posters, reports), news writing and editing, social media strategy, website programming',
#         'internal and external communication, graphic design/marketing (brochures, posters, reports), data collection tools, event/open houses',
#         'internal and external communication, graphic design/marketing (brochures, posters, reports), data collection tools',
#         'graphic design/marketing (brochures, posters, reports), news writing and editing',
#         'internal and external communication, executive-level documentation, graphic design/marketing (brochures, posters, reports), website programming',
#         'website programming, news writing and editing',
#         'internal and external communication, communication planning/strategy, graphic design/marketing (brochures, posters, reports)',
#         'internal and external communication, news writing and editing'],
#        dtype=object),
#  array(['web programming', 'no skill',
#         'video editing, graphic design, technical documentation, news and media communication',
#         'technical documentation, writing and editing, graphic design, proofreading and quality assurance',
#         'graphic design, proofreading and quality assurance, writing and editing, technical documentation',
#         'technical documentation',
#         'graphic design, proofreading and quality assurance, writing and editing, video editing, technical documentation',
#         'social media strategy, graphic design, video editing, writing and editing, public outreach and engagement, proofreading and quality assurance',
#         'public outreach and engagement, writing and editing, social media strategy, video editing and production',
#         'graphic design', 'social media strategy',
#         'video editing, technical documentation, graphic design, proofreading and quality assurance',
#         'video production and editing',
#         'technical documentation, graphic design',
#         'technical documentation, proofreading and quality assurance, graphic design',
#         'technical documentation, graphic design, proofreading and quality assurance',
#         'social media strategy, video editing and production',
#         'graphic design, proofreading and quality assurance',
#         'social media strategy, website programming, graphic design',
#         'graphic design, technical documentation',
#         'website programming, graphic design, proofreading and quality assurance',
#         'graphic design, website programming',
#         'technical documentation, website programming, graphic design',
#         'technical documentation, website programming',
#         'video editing, graphic design',
#         'social media strategy, website programming',
#         'social media strategy, graphic design, writing and editing',
#         'proofreading and quality assurance',
#         'proofreading and quality assurance, news and media communication',
#         'social media strategy, graphic design',
#         'social media strategy, graphic design, technical documentation, video editing',
#         'graphic design, proofreading and quality assurance, public relations, news and media communication, writing and editing, video editing and production, website programming, social media strategy, public outreach and engagement, video editing, technical documentation',
#         'graphic design, technical documentation, social media strategy, website programming',
#         'graphic design, proofreading and quality assurance, social media strategy',
#         'technical documentation, graphic design, social media strategy, video editing and production',
#         'social media strategy, writing and editing',
#         'graphic design, proofreading and quality assurance, technical documentation, social media strategy, website programming',
#         'news and media communication, graphic design', 'video editing',
#         'news and media communication',
#         'video editing and production, website programming, social media strategy',
#         'proofreading and quality assurance, website programming, news and media communication',
#         'graphic design, writing and editing, technical documentation, video editing',
#         'graphic design, website programming, social media strategy',
#         'proofreading and quality assurance, website programming, graphic design',
#         'technical documentation, graphic design, writing and editing',
#         'website programming, technical documentation, graphic design',
#         'technical documentation, graphic design, website programming',
#         'video editing and production, proofreading and quality assurance, graphic design',
#         'graphic design, social media strategy',
#         'technical documentation, graphic design, writing and editing, proofreading and quality assurance',
#         'website programming, technical documentation, proofreading and quality assurance',
#         'writing and editing, website programming',
#         'public outreach and engagement',
#         'website programming, graphic design, writing and editing, proofreading and quality assurance, video editing',
#         'social media strategy, website programming, graphic design, proofreading and quality assurance, writing and editing, video editing and production, public outreach and engagement',
#         'graphic design, website programming, writing and editing, proofreading and quality assurance, technical documentation',
#         'writing and editing, website programming, graphic design, proofreading and quality assurance, video editing, technical documentation',
#         'graphic design, technical documentation, website programming',
#         'social media strategy, graphic design, writing and editing, proofreading and quality assurance',
#         'writing and editing',
#         'writing and editing, website programming, graphic design',
#         'graphic design, technical documentation, website programming, social media strategy, proofreading and quality assurance, public outreach and engagement',
#         'website programming, proofreading and quality assurance, graphic design',
#         'proofreading and quality assurance, graphic design, technical documentation, writing and editing',
#         'graphic design, public relations, video editing and production, video editing',
#         'internal and external communication, proofreading and quality assurance',
#         'internal and external communication, proofreading and quality assurance, graphic design, social media strategy, technical documentation',
#         'graphic design, writing and editing, technical documentation',
#         'writing and editing, internal and external communication',
#         'graphic design, proofreading and quality assurance, public outreach and engagement',
#         'graphic design, proofreading and quality assurance, technical documentation',
#         'writing and editing, news and media communication',
#         'graphic design, proofreading and quality assurance, website programming',
#         'public outreach and engagement, technical documentation, graphic design',
#         'proofreading and quality assurance, internal and external communication',
#         'graphic design, proofreading and quality assurance, website programming, social media strategy',
#         'public outreach and engagement, writing and editing, proofreading and quality assurance, graphic design, social media strategy',
#         'video editing, social media strategy',
#         'proofreading and quality assurance, internal and external communication, social media strategy',
#         'writing and editing, news and media communication, proofreading and quality assurance',
#         'proofreading and quality assurance, news and media communication, website programming, writing and editing, internal and external communication',
#         'website programming, graphic design',
#         'internal and external communication',
#         'graphic design, writing and editing',
#         'writing and editing, proofreading and quality assurance',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, survey design and data analysis',
#         'proofreading and quality assurance, writing and editing, news and media communication',
#         'news and media communication, writing and editing, proofreading and quality assurance',
#         'proofreading and quality assurance, news and media communication, video editing and production',
#         'proofreading and quality assurance, writing and editing',
#         'website programming, writing and editing',
#         'writing and editing, proofreading and quality assurance, internal and external communication',
#         'writing and editing, social media strategy, graphic design',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, technical documentation',
#         'proofreading and quality assurance, public outreach and engagement, writing and editing',
#         'writing and editing, proofreading and quality assurance, graphic design',
#         'graphic design, proofreading and quality assurance, social media strategy, video editing and production, website programming, writing and editing',
#         'writing and editing, technical documentation, graphic design',
#         'writing and editing, graphic design',
#         'public relations, writing and editing', 'public relations',
#         'proofreading and quality assurance, graphic design, website programming',
#         'news and media communication, writing and editing',
#         'writing and editing, website programming, video editing and production, social media strategy, event coordination',
#         'writing and editing, website programming, event coordination, social media strategy, video editing and production',
#         'graphic design, proofreading and quality assurance, website programming, writing and editing',
#         'writing and editing, news and media communication, public relations',
#         'proofreading and quality assurance, public relations',
#         'proofreading and quality assurance, video editing and production',
#         'graphic design, proofreading and quality assurance, technical documentation, writing and editing',
#         'graphic design, proofreading and quality assurance, writing and editing',
#         'public outreach and engagement, graphic design, video editing and production, website programming, writing and editing, social media strategy',
#         'graphic design, proofreading and quality assurance, video editing and production, website programming, writing and editing',
#         'event coordination',
#         'graphic design, writing and editing, public outreach and engagement',
#         'social media strategy, writing and editing, video editing',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, website programming, writing and editing, video editing and production, social media strategy',
#         'video editing and production, website programming',
#         'video editing and production, writing and editing, proofreading and quality assurance',
#         'proofreading and quality assurance, writing and editing, technical documentation',
#         'public outreach and engagement, proofreading and quality assurance, writing and editing, website programming',
#         'writing and editing, social media strategy',
#         'proofreading and quality assurance, website programming',
#         'graphic design, proofreading and quality assurance, writing and editing, website programming',
#         'proofreading and quality assurance, writing and editing, public relations',
#         'graphic design, proofreading and quality assurance, writing and editing, social media strategy',
#         'writing and editing, public outreach and engagement',
#         'public outreach and engagement, graphic design, writing and editing',
#         'video editing, proofreading and quality assurance',
#         'writing and editing, proofreading and quality assurance, public relations',
#         'video editing and production, proofreading and quality assurance, writing and editing',
#         'website programming, writing and editing, proofreading and quality assurance',
#         'proofreading and quality assurance, graphic design, website programming, writing and editing',
#         'public relations, writing and editing, proofreading and quality assurance, website programming',
#         'proofreading and quality assurance, website programming, writing and editing',
#         'proofreading and quality assurance, writing and editing, website programming',
#         'writing and editing, news and media communication, website programming',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, website programming, social media strategy, writing and editing',
#         'public outreach and engagement, writing and editing, website programming, proofreading and quality assurance',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, website programming, writing and editing',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, website programming',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, writing and editing, website programming',
#         'graphic design, proofreading and quality assurance, public relations, social media strategy, video editing and production, writing and editing',
#         'public relations, writing and editing, news and media communication, proofreading and quality assurance',
#         'news and media communication, public relations',
#         'proofreading and quality assurance, video editing and production, website programming, writing and editing, social media strategy',
#         'proofreading and quality assurance, writing and editing, video editing and production, website programming',
#         'public relations, proofreading and quality assurance, writing and editing, website programming',
#         'writing and editing, proofreading and quality assurance, website programming',
#         'writing and editing, public relations',
#         'public relations, video editing and production, website programming, writing and editing, social media strategy',
#         'website programming, graphic design, writing and editing',
#         'writing and editing, website programming, public relations',
#         'writing and editing, social media strategy, website programming, public relations, news and media communication',
#         'public relations, website programming, writing and editing',
#         'public relations, social media strategy',
#         'social media strategy, public relations',
#         'public relations, news and media communication, social media strategy, website programming, writing and editing',
#         'proofreading and quality assurance, graphic design, writing and editing, website programming',
#         'writing and editing, video editing and production, website programming, social media strategy',
#         'video editing and production, website programming, writing and editing',
#         'graphic design, proofreading and quality assurance, public relations, news and media communication, social media strategy, technical documentation, website programming, writing and editing',
#         'video editing and production, website programming, writing and editing, social media strategy',
#         'social media strategy, video editing and production, website programming, writing and editing, proofreading and quality assurance',
#         'writing and editing, website programming, graphic design, proofreading and quality assurance',
#         'website programming, writing and editing, graphic design, proofreading and quality assurance',
#         'internal and external communication, video editing and production',
#         'website programming, writing and editing, proofreading and quality assurance, graphic design',
#         'graphic design, proofreading and quality assurance, video editing and production',
#         'video editing and production, internal and external communication',
#         'video editing and production, writing and editing',
#         'internal and external communication, website programming, proofreading and quality assurance, writing and editing',
#         'proofreading and quality assurance, technical documentation, writing and editing',
#         'writing and editing, internal and external communication, website programming',
#         'website programming, graphic design, news and media communication',
#         'website programming, proofreading and quality assurance',
#         'website programming, news and media communication',
#         'internal and external communication, website programming',
#         'video editing and production, social media strategy',
#         'website programming, internal and external communication',
#         'website programming, video editing and production',
#         'proofreading and quality assurance, event coordination',
#         'proofreading and quality assurance, news and media communication, website programming',
#         'proofreading and quality assurance, internal and external communication, website programming',
#         'website programming, public outreach and engagement',
#         'graphic design, proofreading and quality assurance, writing and editing, video editing',
#         'graphic design, proofreading and quality assurance, video editing',
#         'graphic design, proofreading and quality assurance, social media strategy, video editing, writing and editing',
#         'graphic design, public outreach and engagement',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, website programming',
#         'proofreading and quality assurance, public relations, news and media communication',
#         'public outreach and engagement, graphic design',
#         'technical documentation, graphic design, proofreading and quality assurance, public outreach and engagement',
#         'public outreach and engagement, graphic design, website programming, writing and editing',
#         'graphic design, public outreach and engagement, social media strategy',
#         'public outreach and engagement, graphic design, proofreading and quality assurance',
#         'proofreading and quality assurance, graphic design, technical documentation',
#         'public outreach and engagement, public relations, proofreading and quality assurance, news and media communication',
#         'video editing, public outreach and engagement, proofreading and quality assurance, graphic design, social media strategy',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, social media strategy',
#         'public outreach and engagement, website programming, writing and editing',
#         'news and media communication, social media strategy',
#         'proofreading and quality assurance, social media strategy, news and media communication',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, social media strategy',
#         'public outreach and engagement, graphic design, social media strategy, proofreading and quality assurance',
#         'public outreach and engagement, website programming',
#         'public outreach and engagement, news and media communication, writing and editing, proofreading and quality assurance',
#         'public outreach and engagement, proofreading and quality assurance, public relations, news and media communication',
#         'public outreach and engagement, social media strategy',
#         'public relations, news and media communication',
#         'public outreach and engagement, graphic design, social media strategy',
#         'video editing and production, proofreading and quality assurance, graphic design, social media strategy',
#         'public outreach and engagement, public relations, proofreading and quality assurance, writing and editing',
#         'social media strategy, website programming, graphic design, writing and editing, public relations, news and media communication, public outreach and engagement',
#         'social media strategy, video editing and production, proofreading and quality assurance',
#         'public outreach and engagement, graphic design, news and media communication, website programming, writing and editing',
#         'public outreach and engagement, public relations, writing and editing, news and media communication',
#         'public outreach and engagement, social media strategy, graphic design, website programming, proofreading and quality assurance, event coordination, public relations, news and media communication, technical documentation',
#         'public outreach and engagement, news and media communication, proofreading and quality assurance, writing and editing',
#         'public outreach and engagement, social media strategy, graphic design',
#         'news and media communication, proofreading and quality assurance',
#         'proofreading and quality assurance, graphic design',
#         'social media strategy, graphic design, public outreach and engagement',
#         'social media strategy, graphic design, technical documentation',
#         'public outreach and engagement, news and media communication, proofreading and quality assurance',
#         'public outreach and engagement, writing and editing',
#         'graphic design, public outreach and engagement, technical documentation',
#         'public outreach and engagement, graphic design, technical documentation',
#         'public outreach and engagement, social media strategy, graphic design, proofreading and quality assurance, writing and editing',
#         'public outreach and engagement, proofreading and quality assurance, video editing',
#         'social media strategy, public outreach and engagement, graphic design',
#         'video editing and production, public relations',
#         'news and media communication, public outreach and engagement',
#         'video editing, public relations',
#         'public outreach and engagement, technical documentation',
#         'social media strategy, public outreach and engagement, website programming',
#         'video editing and production, proofreading and quality assurance',
#         'public outreach and engagement, proofreading and quality assurance',
#         'proofreading and quality assurance, public outreach and engagement, public relations',
#         'proofreading and quality assurance, website programming, public outreach and engagement',
#         'public outreach and engagement, proofreading and quality assurance, graphic design',
#         'social media strategy, public outreach and engagement',
#         'website programming, public outreach and engagement, graphic design, proofreading and quality assurance',
#         'graphic design, proofreading and quality assurance, social media strategy, website programming, news and media communication',
#         'graphic design, proofreading and quality assurance, internal and external communication, writing and editing',
#         'graphic design, proofreading and quality assurance, internal and external communication',
#         'graphic design, technical documentation, proofreading and quality assurance, public outreach and engagement',
#         'internal and external communication, graphic design',
#         'public outreach and engagement, news and media communication, public relations',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, social media strategy, news and media communication',
#         'proofreading and quality assurance, graphic design, internal and external communication',
#         'proofreading and quality assurance, social media strategy',
#         'graphic design, social media strategy, website programming, public outreach and engagement',
#         'proofreading and quality assurance, technical documentation, graphic design',
#         'graphic design, proofreading and quality assurance, news and media communication',
#         'graphic design, proofreading and quality assurance, social media strategy, news and media communication',
#         'internal and external communication, event coordination',
#         'graphic design, internal and external communication, technical documentation',
#         'news and media communication, social media strategy, website programming, graphic design, proofreading and quality assurance',
#         'public outreach and engagement, website programming, video editing and production',
#         'video editing and production, social media strategy, public outreach and engagement',
#         'public outreach and engagement, social media strategy, website programming',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, internal and external communication, website programming',
#         'internal and external communication, website programming, survey design and data analysis',
#         'internal and external communication, website programming, graphic design, proofreading and quality assurance',
#         'public outreach and engagement, website programming, graphic design, proofreading and quality assurance, public relations, news and media communication, writing and editing',
#         'public outreach and engagement, social media strategy, website programming, proofreading and quality assurance',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, technical documentation',
#         'proofreading and quality assurance, social media strategy, graphic design, public outreach and engagement, news and media communication',
#         'public outreach and engagement, social media strategy, proofreading and quality assurance, news and media communication',
#         'public outreach and engagement, video editing and production, proofreading and quality assurance, social media strategy',
#         'public outreach and engagement, proofreading and quality assurance, website programming, survey design and data analysis',
#         'public outreach and engagement, public relations',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, news and media communication, social media strategy, website programming',
#         'social media strategy, website programming, graphic design, news and media communication',
#         'video editing and production, public outreach and engagement',
#         'survey design and data analysis, internal and external communication',
#         'public outreach and engagement, news and media communication, website programming, graphic design, proofreading and quality assurance, public relations',
#         'graphic design, public outreach and engagement, proofreading and quality assurance',
#         'public outreach and engagement, website programming, social media strategy',
#         'graphic design, social media strategy, video editing and production',
#         'survey design and data analysis, public outreach and engagement, website programming, data collection tools',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, data collection tools',
#         'public outreach and engagement, social media strategy, graphic design, proofreading and quality assurance, news and media communication',
#         'graphic design, proofreading and quality assurance, internal and external communication, website programming',
#         'survey design and data analysis, internal and external communication, event coordination',
#         'public outreach and engagement, video editing, website programming',
#         'graphic design, proofreading and quality assurance, social media strategy, news and media communication, website programming',
#         'graphic design, proofreading and quality assurance, news and media communication, website programming, social media strategy',
#         'social media strategy, graphic design, news and media communication, website programming',
#         'public outreach and engagement, proofreading and quality assurance, social media strategy',
#         'public outreach and engagement, graphic design, social media strategy, website programming',
#         'graphic design, public outreach and engagement, website programming',
#         'public outreach and engagement, public relations, news and media communication, website programming',
#         'public outreach and engagement, social media strategy, video editing and production',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, website programming, news and media communication, social media strategy',
#         'public outreach and engagement, social media strategy, website programming, news and media communication',
#         'public outreach and engagement, video editing and production',
#         'website programming, social media strategy, public outreach and engagement, graphic design, proofreading and quality assurance, news and media communication',
#         'public outreach and engagement, writing and editing, proofreading and quality assurance',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, technical documentation, social media strategy',
#         'public outreach and engagement, proofreading and quality assurance, graphic design, video editing and production, website programming, social media strategy',
#         'graphic design, website programming, data collection tools, internal and external communication',
#         'proofreading and quality assurance, survey design and data analysis, data collection tools',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, writing and editing, social media strategy',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, social media strategy, video editing and production',
#         'public outreach and engagement, website programming, data collection tools',
#         'graphic design, proofreading and quality assurance, website programming, internal and external communication',
#         'public outreach and engagement, graphic design, website programming',
#         'survey design and data analysis, public outreach and engagement, website programming',
#         'public outreach and engagement, graphic design, social media strategy, news and media communication',
#         'public outreach and engagement, internal and external communication',
#         'graphic design, public outreach and engagement, social media strategy, news and media communication, website programming',
#         'public outreach and engagement, graphic design, website programming, news and media communication, social media strategy',
#         'public outreach and engagement, graphic design, event coordination, website programming',
#         'public outreach and engagement, website programming, proofreading and quality assurance',
#         'public outreach and engagement, proofreading and quality assurance, news and media communication, website programming, social media strategy',
#         'graphic design, presentation design',
#         'proofreading and quality assurance, data collection tools',
#         'technical documentation, public outreach and engagement, graphic design',
#         'internal and external communication, graphic design, website programming',
#         'public outreach and engagement, website programming, graphic design',
#         'public outreach and engagement, graphic design, news and media communication, technical documentation, website programming, social media strategy',
#         'public outreach and engagement, graphic design, technical documentation, video editing and production, website programming',
#         'video editing, website programming',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, technical documentation, website programming',
#         'public outreach and engagement, graphic design, proofreading and quality assurance, event coordination, technical documentation, website programming, social media strategy, video editing and production',
#         'writing and editing, video editing and production, social media strategy',
#         'writing and editing, proofreading and quality assurance, public outreach and engagement',
#         'internal and external communication, proofreading and quality assurance, writing and editing',
#         'public relations, news and media communication, proofreading and quality assurance, social media strategy, writing and editing',
#         'public relations, website programming, social media strategy',
#         'public relations, website programming',
#         'proofreading and quality assurance, news and media communication, website programming, writing and editing',
#         'writing and editing, event coordination',
#         'public relations, social media strategy, writing and editing',
#         'public outreach and engagement, event coordination, social media strategy',
#         'news and media communication, website programming, social media strategy, public relations',
#         'news and media communication, writing and editing, proofreading and quality assurance, social media strategy',
#         'public relations, news and media communication, website programming, writing and editing, video editing and production, social media strategy',
#         'graphic design, website programming, internal and external communication',
#         'public outreach and engagement, news and media communication, writing and editing, website programming, proofreading and quality assurance',
#         'internal and external communication, proofreading and quality assurance, website programming',
#         'news and media communication, writing and editing, website programming, proofreading and quality assurance',
#         'news and media communication, writing and editing, website programming',
#         'news and media communication, public outreach and engagement, website programming, proofreading and quality assurance',
#         'news and media communication, proofreading and quality assurance, writing and editing, public outreach and engagement, website programming',
#         'proofreading and quality assurance, news and media communication, writing and editing, website programming',
#         'event coordination, writing and editing, technical documentation',
#         'website programming, proofreading and quality assurance, news and media communication',
#         'event coordination, graphic design, technical documentation',
#         'news and media communication, proofreading and quality assurance, website programming',
#         'internal and external communication, website programming, proofreading and quality assurance',
#         'internal and external communication, writing and editing, proofreading and quality assurance, website programming',
#         'proofreading and quality assurance, writing and editing, news and media communication, website programming',
#         'news and media communication, writing and editing, proofreading and quality assurance, website programming',
#         'proofreading and quality assurance, news and media communication, writing and editing',
#         'graphic design, internal and external communication, website programming',
#         'graphic design, internal and external communication',
#         'public outreach and engagement, proofreading and quality assurance, news and media communication, writing and editing, website programming',
#         'writing and editing, proofreading and quality assurance, news and media communication, website programming',
#         'news and media communication, proofreading and quality assurance, writing and editing',
#         'writing and editing, internal and external communication, graphic design, website programming',
#         'news and media communication, website programming',
#         'proofreading and quality assurance, public outreach and engagement',
#         'public outreach and engagement, proofreading and quality assurance, website programming, news and media communication',
#         'proofreading and quality assurance, website programming, writing and editing, news and media communication',
#         'news and media communication, website programming, proofreading and quality assurance',
#         'proofreading and quality assurance, technical documentation',
#         'writing and editing, technical documentation',
#         'internal and external communication, website programming, writing and editing',
#         'graphic design, website programming, writing and editing',
#         'graphic design, writing and editing, event coordination',
#         'event coordination, graphic design',
#         'proofreading and quality assurance, writing and editing, website programming, graphic design',
#         'writing and editing, graphic design, website programming',
#         'website programming, writing and editing, graphic design',
#         'proofreading and quality assurance, website programming, news and media communication, writing and editing',
#         'news and media communication, proofreading and quality assurance, website programming, writing and editing',
#         'proofreading and quality assurance, writing and editing, website programming, news and media communication',
#         'website programming, news and media communication, proofreading and quality assurance',
#         'writing and editing, website programming, news and media communication',
#         'news and media communication, proofreading and quality assurance, website programming, graphic design',
#         'news and media communication, website programming, graphic design',
#         'proofreading and quality assurance, website programming, news and media communication, graphic design',
#         'graphic design, writing and editing, website programming',
#         'graphic design, website programming, news and media communication',
#         'proofreading and quality assurance, website programming, internal and external communication',
#         'news and media communication, website programming, writing and editing',
#         'website programming, graphic design, internal and external communication',
#         'event coordination, writing and editing',
#         'proofreading and quality assurance, internal and external communication, graphic design',
#         'internal and external communication, graphic design, proofreading and quality assurance',
#         'website programming, event coordination, public outreach and engagement',
#         'internal and external communication, writing and editing',
#         'social media strategy, technical documentation, public outreach and engagement, public relations, graphic design, video editing, writing and editing',
#         'graphic design, internal and external communication, writing and editing, website programming',
#         'graphic design, writing and editing, internal and external communication, website programming',
#         'internal and external communication, writing and editing, website programming',
#         'internal and external communication, website programming, graphic design',
#         'internal and external communication, writing and editing, website programming, graphic design',
#         'graphic design, internal and external communication, website programming, writing and editing',
#         'internal and external communication, graphic design, writing and editing, website programming',
#         'internal and external communication, website programming, writing and editing, graphic design',
#         'internal and external communication, graphic design, proofreading and quality assurance, website programming',
#         'survey design and data analysis, internal and external communication, graphic design, proofreading and quality assurance',
#         'survey design and data analysis, proofreading and quality assurance, internal and external communication',
#         'writing and editing, website programming, internal and external communication',
#         'website programming, internal and external communication, proofreading and quality assurance',
#         'data collection tools, graphic design',
#         'graphic design, proofreading and quality assurance, data collection tools',
#         'website programming, data collection tools',
#         'data collection tools',
#         'internal and external communication, graphic design, data collection tools',
#         'website programming, proofreading and quality assurance, internal and external communication',
#         'graphic design, news and media communication, writing and editing, website programming, social media strategy',
#         'internal and external communication, website programming, graphic design, data collection tools, writing and editing',
#         'graphic design, data collection tools',
#         'internal and external communication, graphic design, event coordination, data collection tools, website programming, writing and editing',
#         'internal and external communication, writing and editing, graphic design',
#         'writing and editing, website programming, internal and external communication, graphic design',
#         'graphic design, internal and external communication, writing and editing',
#         'presentation design, graphic design',
#         'internal and external communication, proofreading and quality assurance, graphic design, website programming',
#         'graphic design, internal and external communication, presentation design',
#         'graphic design, internal and external communication, website programming, writing and editing, survey design and data analysis, data collection tools',
#         'data collection tools, website programming',
#         'internal and external communication, graphic design, website programming, event coordination, writing and editing',
#         'graphic design, internal and external communication, technical documentation, website programming',
#         'survey design and data analysis, internal and external communication, website programming, proofreading and quality assurance',
#         'internal and external communication, graphic design, website programming, proofreading and quality assurance',
#         'internal and external communication, proofreading and quality assurance, graphic design',
#         'graphic design, internal and external communication, website programming, proofreading and quality assurance',
#         'graphic design, internal and external communication, website programming, social media strategy',
#         'graphic design, writing and editing, internal and external communication',
#         'website programming, video editing and production, graphic design, news and media communication',
#         'internal and external communication, news and media communication'],
#        dtype=object))

# %%
print(df['RequiredSkill'].unique())
# Out:
# ['web programming' 'video production and editing'
#  'graphic design/marketing (posters, brochures, reports)'
#  'social media strategy' 'technical writing' 'news writing and editing'
#  'strategic planning and project management'
#  'graphic design/marketing (posters, brochures, reports), social media strategy'
#  'unknoun'
#  'website programming, graphic design/marketing (posters, brochures, reports)'
#  'graphic design/marketing (posters, brochures, reports), social media strategy, website programming, technical writing'
#  'video editing and production, website programming'
#  'graphic design/marketing (posters, brochures, reports), social media strategy, website programming'
#  'social media strategy, graphic design/marketing (posters, brochures, reports)'
#  'graphic design/marketing (posters, brochures, reports), video editing and production'
#  'internal and external communication, news writing and editing, graphic design/marketing (posters, brochures, reports)'
#  'internal and external communication, public relations'
#  'social media strategy, video editing and production, website programming'
#  'printed material (posters, brochures, reports)'
#  'internal and external communication'
#  'internal and external communication, graphic design/marketing (posters, brochures, reports), social media strategy, strategic planning and project management'
#  'strategic planning and project management, graphic design/marketing (posters, brochures, reports)'
#  'graphic design/marketing (brochures, posters, reports)'
#  'graphic design/marketing (brochures, posters, reports), communication planning/strategy'
#  'communication planning/strategy, technical writing'
#  'communication planning/strategy'
#  'communication planning/strategy, graphic design/marketing (brochures, posters, reports)'
#  'social media strategy, technical writing'
#  'graphic design/marketing (brochures, posters, reports), social media strategy'
#  'communication planning/strategy, social media strategy, graphic design/marketing (brochures, posters, reports)'
#  'communication planning/strategy, internal and external communication, social media strategy'
#  'communication planning/strategy, news writing and editing, website programming'
#  'website programming, graphic design/marketing (brochures, posters, reports)'
#  'communication planning/strategy, internal and external communication'
#  'communication planning/strategy, graphic design/marketing (brochures, posters, reports), social media strategy'
#  'communication planning/strategy, data collection tools, graphic design/marketing (brochures, posters, reports)'
#  'news writing and editing, social media strategy'
#  'news writing and editing, video editing and production'
#  'communication planning/strategy, public relations, news writing and editing'
#  'social media strategy, communication planning/strategy'
#  'communication planning/strategy, internal and external communication, social media strategy, video editing and production'
#  'social media strategy, graphic design/marketing (brochures, posters, reports)'
#  'communication planning/strategy, internal and external communication, data collection tools, website programming'
#  'communication planning/strategy, news writing and editing, video editing and production'
#  'graphic design/marketing (brochures, posters, reports), social media strategy, news writing and editing'
#  'issue and risk management' 'public relations'
#  'event management and logistics'
#  'news writing and editing, website programming, social media strategy'
#  'public relations, website programming, news writing and editing'
#  'graphic design/marketing (posters, brochures, reports), technical writing'
#  'social media strategy, public relations'
#  'public relations, social media strategy'
#  'strategic planning and project management, public relations, technical writing, website programming, news writing and editing'
#  'video editing and production, website programming, social media strategy'
#  'issue and risk management, social media strategy, video editing and production, website programming'
#  'strategic planning and project management, issue and risk management, public relations, news writing and editing, graphic design/marketing (posters, brochures, reports), social media strategy, website programming'
#  'website programming, video editing and production, social media strategy'
#  'graphic design/marketing (posters, brochures, reports), website programming'
#  'public relations, technical writing'
#  'internal and external communication, video editing and production'
#  'video editing and production, internal and external communication'
#  'website programming, communication planning/strategy'
#  'website programming, internal and external communication'
#  'graphic design/marketing (brochures, posters, reports), website programming'
#  'video editing and production, social media strategy'
#  'website programming, video editing and production'
#  'internal and external communication, website programming'
#  'website programming, data collection tools'
#  'event management and logistics, graphic design/marketing (posters, brochures, reports), news writing and editing, social media strategy, website programming'
#  'strategic planning and project management, website programming'
#  'internal and external communication, graphic design/marketing (posters, brochures, reports)'
#  'event management and logistics, social media strategy, graphic design/marketing (posters, brochures, reports)'
#  'internal and external communication, technical writing'
#  'social media strategy, news writing and editing, graphic design/marketing (posters, brochures, reports)'
#  'strategic planning and project management, technical writing'
#  'social media strategy, news writing and editing'
#  'graphic design/marketing (posters, brochures, reports), strategic planning and project management'
#  'social media strategy, graphic design/marketing (posters, brochures, reports), news writing and editing'
#  'strategic planning and project management, graphic design/marketing (posters, brochures, reports), technical writing'
#  'graphic design/marketing (posters, brochures, reports), event management and logistics'
#  'event management and logistics, strategic planning and project management, internal and external communication'
#  'website programming, strategic planning and project management'
#  'graphic design/marketing (posters, brochures, reports), website programming, social media strategy, news writing and editing'
#  'strategic planning and project management, event management and logistics, technical writing, video editing and production, website programming'
#  'strategic planning and project management, graphic design/marketing (posters, brochures, reports), social media strategy, video editing and production'
#  'website programming, graphic design/marketing (posters, brochures, reports), strategic planning and project management, technical writing'
#  'website programming, social media strategy, strategic planning and project management'
#  'internal and external communication, graphic design/marketing (posters, brochures, reports), website programming'
#  'internal and external communication, website programming, graphic design/marketing (posters, brochures, reports)'
#  'news writing and editing, social media strategy, website programming, public relations, graphic design/marketing (posters, brochures, reports)'
#  'strategic planning and project management, social media strategy, website programming'
#  'website programming, strategic planning and project management, data collection tools'
#  'strategic planning and project management, graphic design/marketing (posters, brochures, reports), social media strategy, website programming'
#  'strategic planning and project management, social media strategy'
#  'social media strategy, event management and logistics, news writing and editing'
#  'strategic planning and project management, news writing and editing, social media strategy'
#  'social media strategy, video editing and production'
#  'data collection tools, website programming'
#  'communication planning/strategy, public relations'
#  'news writing and editing, website programming, graphic design/marketing (brochures, posters, reports), communication planning/strategy, event/open houses'
#  'news writing and editing, event/open houses, social media strategy'
#  'internal and external communication, graphic design/marketing (brochures, posters, reports)'
#  'video editing and production, communication planning/strategy'
#  'event/open houses, social media strategy, graphic design/marketing (brochures, posters, reports), news writing and editing'
#  'website programming, social media strategy, communication planning/strategy'
#  'social media strategy, graphic design/marketing (brochures, posters, reports), video editing and production'
#  'executive-level documentation'
#  'graphic design/marketing (brochures, posters, reports), internal and external communication'
#  'communication planning/strategy, website programming'
#  'website programming, communication planning/strategy, data collection tools'
#  'social media strategy, event/open houses, graphic design/marketing (brochures, posters, reports), website programming, news writing and editing'
#  'internal and external communication, event/open houses'
#  'website programming, graphic design/marketing (brochures, posters, reports), communication planning/strategy'
#  'news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports), website programming'
#  'news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)'
#  'news writing and editing, website programming, graphic design/marketing (brochures, posters, reports), social media strategy'
#  'news writing and editing, graphic design/marketing (brochures, posters, reports), social media strategy'
#  'graphic design/marketing (brochures, posters, reports), website programming, social media strategy'
#  'event/open houses, graphic design/marketing (brochures, posters, reports), social media strategy'
#  'news writing and editing, website programming'
#  'event/open houses, social media strategy'
#  'graphic design/marketing (brochures, posters, reports), social media strategy, communication planning/strategy'
#  'social media strategy, news writing and editing, website programming, graphic design/marketing (brochures, posters, reports)'
#  'news writing and editing, graphic design/marketing (brochures, posters, reports), website programming, social media strategy'
#  'website programming, graphic design/marketing (brochures, posters, reports), social media strategy, news writing and editing'
#  'social media strategy, graphic design/marketing (brochures, posters, reports), technical writing'
#  'technical writing, communication planning/strategy'
#  'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy'
#  'social media strategy, website programming, video editing and production'
#  'graphic design/marketing (brochures, posters, reports), event/open houses, website programming, data collection tools'
#  'technical writing, internal and external communication'
#  'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy, website programming, public relations'
#  'graphic design/marketing (brochures, posters, reports), communication planning/strategy, social media strategy, video editing and production'
#  'data collection tools, communication planning/strategy, website programming'
#  'internal and external communication, graphic design/marketing (brochures, posters, reports), website programming'
#  'graphic design/marketing (brochures, posters, reports), news writing and editing, social media strategy, event/open houses'
#  'website programming, communication planning/strategy, news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)'
#  'event/open houses, social media strategy, communication planning/strategy'
#  'website programming, social media strategy, news writing and editing'
#  'website programming, news writing and editing, social media strategy, graphic design/marketing (brochures, posters, reports)'
#  'communication planning/strategy, event/open houses, graphic design/marketing (brochures, posters, reports), website programming'
#  'event/open houses, social media strategy, news writing and editing, graphic design/marketing (brochures, posters, reports), website programming'
#  'data collection tools'
#  'internal and external communication, website programming, graphic design/marketing (brochures, posters, reports)'
#  'technical writing, event management and logistics'
#  'event management and logistics, graphic design/marketing (posters, brochures, reports)'
#  'graphic design/marketing (posters, brochures, reports), internal and external communication'
#  'internal and external communication, video editing and production, website programming'
#  'strategic planning and project management, internal and external communication'
#  'news writing and editing, internal and external communication'
#  'internal and external communication, data collection tools'
#  'communication planning/strategy, website programming, internal and external communication'
#  'event/open houses, graphic design/marketing (brochures, posters, reports), news writing and editing, social media strategy, website programming'
#  'internal and external communication, graphic design/marketing (brochures, posters, reports), data collection tools, event/open houses'
#  'internal and external communication, graphic design/marketing (brochures, posters, reports), data collection tools'
#  'graphic design/marketing (brochures, posters, reports), news writing and editing'
#  'internal and external communication, executive-level documentation, graphic design/marketing (brochures, posters, reports), website programming'
#  'website programming, news writing and editing'
#  'internal and external communication, communication planning/strategy, graphic design/marketing (brochures, posters, reports)'
#  'internal and external communication, news writing and editing']

# %%
df.shape
# Out:
# (2133, 8)

# %%
df_unique = df.drop_duplicates(keep=False)

print("Original DataFrame:")
print(df)

print("\nDataFrame after removing fully duplicated rows:")
print(df_unique)
# Out:
# Original DataFrame:
#                             SchoolDepartment  \
# 0      quality assurance and risk management
# 1      quality assurance and risk management
# 2      quality assurance and risk management
# 3      quality assurance and risk management
# 4      quality assurance and risk management
# ...                                      ...
# 2128  academic affairs and staff development
# 2129   quality assurance and risk management
# 2130   quality assurance and risk management
# 2131     engineering leadership and strategy
# 2132     engineering leadership and strategy
#
#                                            ProjectTitle  \
# 0             Add Documents to 2020 Core Committee Page
# 1                White River High School Election Video
# 2                          Pet License Roster Web Edits
# 3                                 FJC Shred Event Flyer
# 4                Create Artwork for new Large Dropboxes
# ...                                                 ...
# 2128              2019 Standing Ovation Awards nominees
# 2129  Pierce County to continue mobile voting after ...
# 2130  Pierce County to continue mobile voting after ...
# 2131         Flag lowering to honor Deputy Cooper Dyson
# 2132         Flag lowering to honor Deputy Cooper Dyson
#
#                           Email  \
# 0     kfoulstone0@instagram.com
# 1     kfoulstone0@instagram.com
# 2     kfoulstone0@instagram.com
# 3     kfoulstone0@instagram.com
# 4     kfoulstone0@instagram.com
# ...                         ...
# 2128                    unvalid
# 2129                    unvalid
# 2130                    unvalid
# 2131                    unvalid
# 2132                    unvalid
#
#                                           RequiredSkill  \
# 0                                   Website Programming
# 1                          Video Editing and Production
# 2                                   Website Programming
# 3     Graphic Design/Marketing (Posters, Brochures, ...
# 4     Graphic Design/Marketing (Posters, Brochures, ...
# ...                                                 ...
# 2128                Internal and External Communication
# 2129                           News Writing and Editing
# 2130                           News Writing and Editing
# 2131  Internal and External Communication, News Writ...
# 2132  Internal and External Communication, News Writ...
#
#                           Professors  \
# 0            Fatima Zahra El Idrissi
# 1            Fatima Zahra El Idrissi
# 2            Fatima Zahra El Idrissi
# 3            Fatima Zahra El Idrissi
# 4            Fatima Zahra El Idrissi
# ...                              ...
# 2128  Samira Alaoui, Rachid Khattabi
# 2129    Samira Alaoui, Nawal Chraibi
# 2130    Samira Alaoui, Nawal Chraibi
# 2131    Samira Alaoui, Nawal Chraibi
# 2132    Samira Alaoui, Nawal Chraibi
#
#                                             GainedSkill strartingOrAsgnmtDate  \
# 0                                   Website Programming            04-03-2019
# 1                                              No Skill            04-03-2019
# 2                                   Website Programming            04-03-2019
# 3     Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                              No Skill            11-03-2019
# ...                                                 ...                   ...
# 2128  Proofreading and Quality Assurance, Website Pr...            2019-08-05
# 2129  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2130  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2131  Internal and External Communication, News and ...            23-12-2019
# 2132  Internal and External Communication, News and ...            2019-12-23
#
#           Hour
# 0     19:51:00
# 1     19:56:00
# 2     20:12:00
# 3     22:27:00
# 4     15:38:00
# ...        ...
# 2128  19:30:00
# 2129  00:00:00
# 2130  23:40:00
# 2131  00:00:00
# 2132  23:35:00
#
# [2133 rows x 8 columns]
#
# DataFrame after removing fully duplicated rows:
#                             SchoolDepartment  \
# 0      quality assurance and risk management
# 1      quality assurance and risk management
# 2      quality assurance and risk management
# 3      quality assurance and risk management
# 4      quality assurance and risk management
# ...                                      ...
# 2128  academic affairs and staff development
# 2129   quality assurance and risk management
# 2130   quality assurance and risk management
# 2131     engineering leadership and strategy
# 2132     engineering leadership and strategy
#
#                                            ProjectTitle  \
# 0             Add Documents to 2020 Core Committee Page
# 1                White River High School Election Video
# 2                          Pet License Roster Web Edits
# 3                                 FJC Shred Event Flyer
# 4                Create Artwork for new Large Dropboxes
# ...                                                 ...
# 2128              2019 Standing Ovation Awards nominees
# 2129  Pierce County to continue mobile voting after ...
# 2130  Pierce County to continue mobile voting after ...
# 2131         Flag lowering to honor Deputy Cooper Dyson
# 2132         Flag lowering to honor Deputy Cooper Dyson
#
#                           Email  \
# 0     kfoulstone0@instagram.com
# 1     kfoulstone0@instagram.com
# 2     kfoulstone0@instagram.com
# 3     kfoulstone0@instagram.com
# 4     kfoulstone0@instagram.com
# ...                         ...
# 2128                    unvalid
# 2129                    unvalid
# 2130                    unvalid
# 2131                    unvalid
# 2132                    unvalid
#
#                                           RequiredSkill  \
# 0                                   Website Programming
# 1                          Video Editing and Production
# 2                                   Website Programming
# 3     Graphic Design/Marketing (Posters, Brochures, ...
# 4     Graphic Design/Marketing (Posters, Brochures, ...
# ...                                                 ...
# 2128                Internal and External Communication
# 2129                           News Writing and Editing
# 2130                           News Writing and Editing
# 2131  Internal and External Communication, News Writ...
# 2132  Internal and External Communication, News Writ...
#
#                           Professors  \
# 0            Fatima Zahra El Idrissi
# 1            Fatima Zahra El Idrissi
# 2            Fatima Zahra El Idrissi
# 3            Fatima Zahra El Idrissi
# 4            Fatima Zahra El Idrissi
# ...                              ...
# 2128  Samira Alaoui, Rachid Khattabi
# 2129    Samira Alaoui, Nawal Chraibi
# 2130    Samira Alaoui, Nawal Chraibi
# 2131    Samira Alaoui, Nawal Chraibi
# 2132    Samira Alaoui, Nawal Chraibi
#
#                                             GainedSkill strartingOrAsgnmtDate  \
# 0                                   Website Programming            04-03-2019
# 1                                              No Skill            04-03-2019
# 2                                   Website Programming            04-03-2019
# 3     Video Editing, Graphic Design, Technical Docum...            2019-03-04
# 4                                              No Skill            11-03-2019
# ...                                                 ...                   ...
# 2128  Proofreading and Quality Assurance, Website Pr...            2019-08-05
# 2129  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2130  Proofreading and Quality Assurance, Website Pr...            2019-12-03
# 2131  Internal and External Communication, News and ...            23-12-2019
# 2132  Internal and External Communication, News and ...            2019-12-23
#
#           Hour
# 0     19:51:00
# 1     19:56:00
# 2     20:12:00
# 3     22:27:00
# 4     15:38:00
# ...        ...
# 2128  19:30:00
# 2129  00:00:00
# 2130  23:40:00
# 2131  00:00:00
# 2132  23:35:00
#
# [2129 rows x 8 columns]

# %%
df_unique.shape
# Out:
# (2129, 8)
